# %% [markdown]
# # Data Cleaning--Games

# %%
import pandas as pd

# read the Excel file
games = pd.read_excel('/Users/sarahsetiawan/Desktop/CSCAPSTONE/Hood-Hockey/data/instat/Combined_Games.xlsx')
games.head()
# Out:
#     Date                           Opponent Score  Goals  Penalties  \
# 0  08/02              vs Stevenson Mustangs   4:7    4.0        2.0
# 1  23/01                 vs Neumann Knights   1:0    1.0        5.0
# 2  24/01                 vs Neumann Knights   3:4    3.0        5.0
# 3  31/01  vs Lebanon Valley Flying Dutchmen   2:6    2.0        6.0
# 4  07/01                 vs King's Monarchs   1:4    1.0        4.0
#
#    Penalties drawn Penalty time  Faceoffs  Faceoffs won Faceoffs won, %  ...  \
# 0              4.0        04:00        51          26.0             51%  ...
# 1              3.0        10:00        55          28.0             51%  ...
# 2              3.0        10:00        58          25.0             43%  ...
# 3              2.0        12:00        54          19.0             35%  ...
# 4              3.0        08:00        41          20.0             49%  ...
#
#    Faceoffs in NZ  Faceoffs won in NZ  Faceoffs won in NZ, % Faceoffs in OZ  \
# 0              17                 9.0                    53%             18
# 1              10                 7.0                    70%             28
# 2              13                 7.0                    54%             19
# 3              15                 9.0                    60%              9
# 4              12                 7.0                    58%             14
#
#    Faceoffs won in OZ  Faceoffs won in OZ, % Shots  Shots on goal  \
# 0                11.0                    61%  46.0           31.0
# 1                17.0                    61%  82.0           34.0
# 2                 8.0                    42%  58.0           25.0
# 3                 4.0                    44%  41.0           19.0
# 4                 7.0                    50%  34.0           11.0
#
#    Blocked shots        Type
# 0            7.0  GamesTotal
# 1           29.0  GamesTotal
# 2           24.0  GamesTotal
# 3           10.0  GamesTotal
# 4           12.0  GamesTotal
#
# [5 rows x 24 columns]

# %%
print(games.dtypes)
# Out:
# Date                      object
# Opponent                  object
# Score                     object
# Goals                    float64
# Penalties                float64
# Penalties drawn          float64
# Penalty time              object
# Faceoffs                   int64
# Faceoffs won             float64
# Faceoffs won, %           object
# Hits                     float64
# Faceoffs in DZ             int64
# Faceoffs won in DZ       float64
# Faceoffs won in DZ, %     object
# Faceoffs in NZ             int64
# Faceoffs won in NZ       float64
# Faceoffs won in NZ, %     object
# Faceoffs in OZ             int64
# Faceoffs won in OZ       float64
# Faceoffs won in OZ, %     object
# Shots                    float64
# Shots on goal            float64
# Blocked shots            float64
# Type                      object
# dtype: object

# %%
# Remove rows where 'Opponent' contains 'Average'
games_cleaned = games[~games['Opponent'].str.contains('Average', na=False)]

# %%
# Split the 'Score' column into two separate columns
games_cleaned[['Hood Score', 'Opponent Score']] = games_cleaned['Score'].str.split(':', expand=True)

# Convert the new columns to numeric type
games_cleaned['Hood Score'] = pd.to_numeric(games_cleaned['Hood Score']).astype(int)
games_cleaned['Opponent Score'] = pd.to_numeric(games_cleaned['Opponent Score']).astype(int)

# Drop the Score and Goal column
games_cleaned = games_cleaned.drop(columns=['Score', 'Goals'])

# Display the updated dataframe
games_cleaned.head(20)
# Out:
# /var/folders/fn/1h19dxrs6m105yhjv2k86ryr0000gn/T/ipykernel_8154/2679613904.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_cleaned[['Hood Score', 'Opponent Score']] = games_cleaned['Score'].str.split(':', expand=True)
# /var/folders/fn/1h19dxrs6m105yhjv2k86ryr0000gn/T/ipykernel_8154/2679613904.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_cleaned[['Hood Score', 'Opponent Score']] = games_cleaned['Score'].str.split(':', expand=True)
# /var/folders/fn/1h19dxrs6m105yhjv2k86ryr0000gn/T/ipykernel_8154/2679613904.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_cleaned['Hood Score'] = pd.to_numeric(games_cleaned['Hood Score']).astype(int)
# /var/folders/fn/1h19dxrs6m105yhjv2k86ryr0000gn/T/ipykernel_8154/2679613904.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_cleaned['Opponent Score'] = pd.to_numeric(games_cleaned['Opponent Score']).astype(int)
#         Date                                 Opponent  Penalties  \
# 0      08/02                    vs Stevenson Mustangs        2.0
# 1      23/01                       vs Neumann Knights        5.0
# 2      24/01                       vs Neumann Knights        5.0
# 3      31/01        vs Lebanon Valley Flying Dutchmen        6.0
# 4      07/01                       vs King's Monarchs        4.0
# 5   01/11/24                       vs Hilbert College        4.0
# 6      14/02            vs Arcadia University Knights        4.0
# 7   23/11/24                        @ Wilkes Colonels        3.0
# 8   24/11/24                        @ Wilkes Colonels        6.0
# 9   17/11/24                     @ Stevenson Mustangs        3.0
# 10  30/11/24  @ Massachusetts College of Liberal Arts        5.0
# 11  01/12/24  @ Massachusetts College of Liberal Arts        3.0
# 12     17/01         @ Lebanon Valley Flying Dutchmen        3.0
# 13     18/01         @ Lebanon Valley Flying Dutchmen        4.0
# 14     01/02                        @ King's Monarchs        5.0
# 15  08/11/24             @ Arcadia University Knights        5.0
# 16  09/11/24             @ Arcadia University Knights        4.0
# 17     08/02                        @ Alvernia Wolves        7.0
# 19     08/02                    vs Stevenson Mustangs        2.0
# 20     23/01                       vs Neumann Knights        4.0
#
#     Penalties drawn Penalty time  Faceoffs  Faceoffs won Faceoffs won, %  \
# 0               4.0        04:00        51          26.0             51%
# 1               3.0        10:00        55          28.0             51%
# 2               3.0        10:00        58          25.0             43%
# 3               2.0        12:00        54          19.0             35%
# 4               3.0        08:00        41          20.0             49%
# 5               2.0        08:00        71          42.0             59%
# 6               4.0        08:00        52          22.0             42%
# 7               5.0        06:00        56          20.0             36%
# 8               4.0        12:00        57          25.0             44%
# 9               4.0        06:00        49          25.0             51%
# 10              7.0        10:00        63          37.0             59%
# 11              2.0        06:00        51          17.0             33%
# 12              3.0        06:00        51          13.0             25%
# 13              3.0        08:00        53          20.0             38%
# 14              4.0        10:00        58          22.0             38%
# 15              3.0        10:00        54          17.0             31%
# 16              2.0        08:00        46          15.0             33%
# 17              3.0        37:00        46          21.0             46%
# 19              4.0        04:00        41          19.0             46%
# 20              2.0        08:00        37          19.0             51%
#
#     Hits  Faceoffs in DZ  ...  Faceoffs won in NZ, % Faceoffs in OZ  \
# 0    1.0              16  ...                    53%             18
# 1    0.0              17  ...                    70%             28
# 2    0.0              26  ...                    54%             19
# 3    1.0              30  ...                    60%              9
# 4    1.0              15  ...                    58%             14
# 5    0.0              26  ...                    63%             26
# 6    0.0              31  ...                    38%              8
# 7    3.0              35  ...                    55%             10
# 8    0.0              31  ...                    39%              8
# 9    2.0              19  ...                    29%             16
# 10   2.0              19  ...                    67%             32
# 11   1.0              23  ...                    13%             20
# 12   0.0              25  ...                    27%             15
# 13   0.0              24  ...                    46%             16
# 14   1.0              23  ...                    20%             20
# 15   0.0              34  ...                    40%             10
# 16   1.0              31  ...                    14%              8
# 17   2.0              23  ...                    46%             10
# 19   1.0              13  ...                    47%             13
# 20   0.0               9  ...                    78%             19
#
#     Faceoffs won in OZ  Faceoffs won in OZ, % Shots  Shots on goal  \
# 0                 11.0                    61%  46.0           31.0
# 1                 17.0                    61%  82.0           34.0
# 2                  8.0                    42%  58.0           25.0
# 3                  4.0                    44%  41.0           19.0
# 4                  7.0                    50%  34.0           11.0
# 5                 16.0                    62%  75.0           51.0
# 6                  6.0                    75%  24.0           13.0
# 7                  3.0                    30%  15.0            8.0
# 8                  4.0                    50%  19.0           15.0
# 9                 10.0                    63%  46.0           24.0
# 10                19.0                    59%  52.0           29.0
# 11                 5.0                    25%  44.0           23.0
# 12                 4.0                    27%  26.0           16.0
# 13                 7.0                    44%  40.0           10.0
# 14                10.0                    50%  46.0           20.0
# 15                 5.0                    50%  37.0           18.0
# 16                 2.0                    25%  22.0           10.0
# 17                 6.0                    60%  26.0           17.0
# 19                 8.0                    62%  35.0           26.0
# 20                10.0                    53%  62.0           25.0
#
#     Blocked shots        Type  Hood Score  Opponent Score
# 0             7.0  GamesTotal           4               7
# 1            29.0  GamesTotal           1               0
# 2            24.0  GamesTotal           3               4
# 3            10.0  GamesTotal           2               6
# 4            12.0  GamesTotal           1               4
# 5            13.0  GamesTotal           3               2
# 6             7.0  GamesTotal           1               4
# 7             4.0  GamesTotal           0               5
# 8             1.0  GamesTotal           1               7
# 9            16.0  GamesTotal           1               4
# 10           19.0  GamesTotal           1               2
# 11           12.0  GamesTotal           1               2
# 12            6.0  GamesTotal           0               3
# 13           14.0  GamesTotal           1               4
# 14           15.0  GamesTotal           2               3
# 15           11.0  GamesTotal           1               3
# 16            4.0  GamesTotal           0               4
# 17            4.0  GamesTotal           0               4
# 19            5.0          EV           4               7
# 20           22.0          EV           1               0
#
# [20 rows x 24 columns]

# %%
games_cleaned['Date'] = games_cleaned['Date'].astype('datetime64[ms]')

# %%
games_cleaned.to_excel('/Users/sarahsetiawan/Desktop/CSCAPSTONE/Hood-Hockey/DataCleaning/games_cleaned.xlsx', index=False)
